# %% [markdown]
# First Python Program

# %%
# Print Hello World
print("heeeeelllllloooooooooooooooooooooooooooo")

# %% [markdown]
# Python Comments:
#
#
# 1.   Single Line Comment
# 2.   Multi-line Comment

# %%
# meow

"""
meow meow meow meow meow meow meow meow meow meow meow
meow meow meow meow meow meow meow meow meow meow meow
meow meow meow meow meow meow meow meow meow meow meow
meow meow meow meow meow meow meow meow meow meow meow
"""

# %% [markdown]
# **Variables**

# %%
## Creating Variables ##
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it.

x = 8112
print(x)
# Out:
# 3

# %%
# Variables do not need to be decleared with any particular type, and can even change type after they have been set.
x = "jhon"
print(x)
# Out:
# jhon

# %%
# Casting
x = 3.1419
y = str(x).split(".")
print(y)
# Out:
# ['3', '1419']

# %%
# Get the type
print(type(x))
print(type(y))
# Out:
# <class 'float'>
# <class 'list'>

# %%
# Single or Double Quotes?
x = "john"
y = 'john'
print(x == y)
# same shit
# Out:
# True

# %% [markdown]
# **Variables**
#
# **Rules for Python variables:**
#
# *   A variable name must start with a letter or the underscore character
# *   A variable name cannot start with a number
# *   A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# *   Variable names are case-sensitive (age, Age and AGE are three different variables)
# *   A variable name cannot be any of the Python keywords.
#
#
#
#
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it

# %%
## Multi Words Variable Names ##

# There are several techniques you can use to make them more readable:
#1 Camel Case - Each word, except the first, starts with capital letter [myVariableName = "John"]
#2 Pascal Case - Each word starts with a capital letter [MyVariableName = "John"]
#3 Snake Case - Each word is separated by an underscore character [my_variable_name = "John"]

# %%
## Assign multiple values ##

#1 Many values to Multiple variables
x, y, z = "apple", "orange", "cherry"
print(x, y, z)

#Note: Make sure the number of variables matches the number of values, or else you will get an error.


#2 One value to multiple variables
# Out:
# apple orange cherry

# %%
## Unpack a Collection

# If you have a collection of values in a list, tuple, etc. Python allows you to extract the vlaues into variables. This is called unpacking.

# %% [markdown]
# **Output Variables**

# %%
#1
print("hello")

#2
hello = "hello"
world = "world"
print(hello, world)

#3
print(hello + world)

#4
a = 10
b = 20
print(a + b)

#5
a = str(10)
b = str(20)
print(a + b)

#6
a = 10
b = str(20)
print(a + b)

#7

#Note: In the print() function, when you try to combine a string and a number with + operator, Python will give you an error

#8
# Out:
# hello
# hello world
# helloworld
# 30
# 1020
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 25
#      23 a = 10
#      24 b = str(20)
# ---> 25 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **Python Data Types**
#
# In Python, the data type is set when you assign a value to a variable:
#
# ![Screenshot 2025-07-23 055843.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What does mutable mean?**
#
# means you can, add, or remove elements from a list without creating a new list

# %%
# List -> Mutable
x = ["apple", "cherry", 10, "straw"]

print(x)

x[0] = -5

print(x)
# Out:
# ['apple', 'cherry', 10, 'straw']
# [-5, 'cherry', 10, 'straw']

# %%
# tuple -> immutable
x = ("apple", "cherry", 10, "straw")
print(x)

x[1] = -5234234234234234234234234234234
# Out:
# ('apple', 'cherry', 10, 'straw')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 x = ("apple", "cherry", 10, "straw")
#       3 print(x)
# ----> 5 x[1] = -5234234234234234234234234234234
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Dictionary
x = {
    "firstname": "John",
    "lastname": "Wick",
    "age": None,
}

x["age"] = 37

print(x)
# Out:
# {'firstname': 'John', 'lastname': 'Wick', 'age': 37}

# %%
# Set
x = {"apple", "cherry", "apple"}
print(x)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# **Python Numbers**
#
# There are three numeric types in Python:
#
# 1.   int
# 2.   float
# 3.   complex

# %%
# Float can also be scientific numbers with an "e" to indicate the power of 10
f = 3.1419
print(f)

# %% [markdown]
# **Random Number**

# %%
import random

x = random.randrange(1,100)
print(x)
# Out:
# 53

# %% [markdown]
# **Python String**
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks

# %%
# Quotes inside quotes
# you can use quotes inside a string, as long as they don't match the quotes surrounding the string

print('meow meow meow meow "MEOW" meow')
print("MEOW MEOW MEOW MEOW 'meow' MEOW")
# Out:
# meow meow meow meow "MEOW" meow
# MEOW MEOW MEOW MEOW 'meow' MEOW

# %% [markdown]
# **Python If...Else**

# %%
a = 100
b = 200

if(a > b): 
    print(a)
else:
    print(b)
# Out:
# 200

# %%
## Python Indentation ##
if a > b:
    print("a")
elif a == b:
    print("both")
else:
    print("b")
# Out:
# b

# %% [markdown]
# **Operators**

# %%
# And Operator
c = 300

if c > b and c > b:
    print("c is largest")
# Out:
# c is largest

# %%
# Or Operator
c = 300

if c > b or c > b:
    print("c maybe is larger")
# Out:
# c maybe is larger

# %%
# Not Operator
if a != b:
    print("no")

# %%
# Nested If
if a > b:
    if b > c:
        print("AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA")

# %% [markdown]
# Loops:
#
#
# *   while
# *   for

# %%
i = 1
while i < 10:
    print(i)
    if i == 4:
        break
    i += 1
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(3, 10, 2):
    print(i)
# Out:
# 3
# 5
# 7
# 9

# %%
fruits = ["a", "b", "c", "d"]

for f in fruits:
    print(f)
# Out:
# a
# b
# c
# d

# %% [markdown]
# # Slicing

# %%
a = [1,2,3,4,5,6,7,8,9]
a[2:7]
# Out:
# [3, 4, 5, 6, 7]

# %%
a[:7]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a[5:]
# Out:
# [6, 7, 8, 9]

# %%
a[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
a[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
a[-2:]
# Out:
# [8, 9]

# %%
a[:-2]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a[::-1]
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
for i in a[::-1]:
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # Func

# %%
def f():
    print("AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA")

f()
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA

# %%
def sayhi(name):
    print("hi", name)

sayhi("sakamoto")
# Out:
# hi sakamoto

# %%
def multbot(a, b):
    return a*b

print(multbot(4,4))
# Out:
# 16

# %%
def g(*rest):
    # rest[1] = -1
    print(rest)

g("a", "b", "c")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 5
#       2     rest[1] = -1
#       3     print(rest)
# ----> 5 g("a", "b", "c")
#
# Cell In[67], line 2, in g(*rest)
#       1 def g(*rest):
# ----> 2     rest[1] = -1
#       3     print(rest)
#
# TypeError: 'tuple' object does not support item assignment
